# %% [markdown]
# ## Iris Dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. Fisher's paper is a classic in the field and is referenced frequently to this day. (See Duda & Hart, for example.) The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant. One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.

# %%
# Import the important library for data preprocessing, Input-Output of dataset and data visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %matplotlib inline
warnings.filterwarnings("ignore")

df = pd.read_csv('./iris-species/Iris.csv').drop("Id", axis=1)

# %%
feature = df.drop("Species",axis=1)
target  = df["Species"]

# %%
sns.pairplot(df, hue="Species", size=3, diag_kind="kde");

# %%
from sklearn.cross_validation import KFold
from sklearn.naive_bayes import GaussianNB

clf = GaussianNB()
kf = KFold(n=len(feature), n_folds=5, shuffle=False,random_state=42)

for train_index, test_index in kf:
    X_train, X_test = feature.iloc[train_index], feature.iloc[test_index]
    y_train, y_test = target[train_index], target[test_index]

# %%
clf.fit(X_train,y_train);

# %%
clf.score(X_test,y_test)
# Out:
# 0.93333333333333335

# %%
train_sizes, train_scores, test_scores = learning_curve(
        clf, feature, target, cv=kf, n_jobs=0, train_sizes=len(feature))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-983f376d3904> in <module>()
#       1 train_sizes, train_scores, test_scores = learning_curve(
# ----> 2         clf, feature, target, cv=kf, n_jobs=0, train_sizes=len(feature))
#
# TypeError: learning_curve() got an unexpected keyword argument 'cv'
